# %%
import pandas as pd
df = pd.read_csv('Data/blkjckhands.csv')

# %%
df.columns
# Out:
# Index(['PlayerNo', 'card1', 'card2', 'card3', 'card4', 'card5', 'sumofcards',
#        'dealcard1', 'dealcard2', 'dealcard3', 'dealcard4', 'dealcard5',
#        'sumofdeal', 'blkjck', 'winloss', 'plybustbeat', 'dlbustbeat',
#        'plwinamt', 'dlwinamt', 'ply2cardsum'],
#       dtype='object')

# %%
# select columns
y = df.winloss
X = df.drop(columns='winloss')

# %%
# remove # index
X.set_index('PlayerNo', inplace=True)

# %%
# replace all strings for #s
X = pd.get_dummies(X)

# %%
# split data into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
# Select model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# c:\users\seidi\.conda\envs\pythonadv\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression()

# %%
# Prediction score
model.score(X_test,y_test)
# Out:
# 1.0

# %%
X_test
# Out:
#           card1  card2  card3  card4  card5  sumofcards  dealcard1  dealcard2  \
# PlayerNo
# Player5      10     10      0      0      0          20         10          5
# Player4       6      8      0      7      0          21         10          2
# Player3       6      9      0      0      0          15          5         10
# Player6      11     10      0      0      0          21         10         10
# Player4       2     11      7      0      0          20         10          7
# ...         ...    ...    ...    ...    ...         ...        ...        ...
# Player5       2      5      4     10      0          21         10          6
# Player5      10      4      0      0      0          14          5          8
# Player4       3      9      0     10      0          22         10          2
# Player5       5     10      0      0      0          15          3          5
# Player4      11      4      5      0      0          20          2         10
#
#           dealcard3  dealcard4  ...  plybustbeat_Beat  plybustbeat_Bust  \
# PlayerNo                        ...
# Player5           8          0  ...                 0                 0
# Player4           4          9  ...                 0                 0
# Player3           5          0  ...                 1                 0
# Player6           0          0  ...                 0                 0
# Player4           0          0  ...                 0                 0
# ...             ...        ...  ...               ...               ...
# Player5           1          0  ...                 0                 0
# Player5           6          0  ...                 1                 0
# Player4           2          3  ...                 0                 1
# Player5          10          0  ...                 1                 0
# Player4           6          0  ...                 0                 0
#
#           plybustbeat_DlBust  plybustbeat_Plwin  plybustbeat_Push  \
# PlayerNo
# Player5                    1                  0                 0
# Player4                    1                  0                 0
# Player3                    0                  0                 0
# Player6                    0                  1                 0
# Player4                    0                  1                 0
# ...                      ...                ...               ...
# Player5                    0                  1                 0
# Player5                    0                  0                 0
# Player4                    0                  0                 0
# Player5                    0                  0                 0
# Player4                    0                  1                 0
#
#           dlbustbeat_Beat  dlbustbeat_Bust  dlbustbeat_Dlwin  \
# PlayerNo
# Player5                 0                1                 0
# Player4                 0                1                 0
# Player3                 0                0                 1
# Player6                 1                0                 0
# Player4                 1                0                 0
# ...                   ...              ...               ...
# Player5                 1                0                 0
# Player5                 0                0                 1
# Player4                 0                0                 0
# Player5                 0                0                 1
# Player4                 1                0                 0
#
#           dlbustbeat_PlBust  dlbustbeat_Push
# PlayerNo
# Player5                   0                0
# Player4                   0                0
# Player3                   0                0
# Player6                   0                0
# Player4                   0                0
# ...                     ...              ...
# Player5                   0                0
# Player5                   0                0
# Player4                   1                0
# Player5                   0                0
# Player4                   0                0
#
# [225000 rows x 27 columns]

# %%
# Comfirming prediction
# selecting player
player = X_test[0:1]

# %%
# Should get a win
y_test[0:1]
# Out:
# 423940    Win
# Name: winloss, dtype: object

# %%
model.predict(player)
# Out:
# array(['Win'], dtype=object)
