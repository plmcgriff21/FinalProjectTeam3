# %%
import pandas as pd
df = pd.read_csv('Data/blkjckhands.csv')

# %%
df.columns
# Out:
# Index(['PlayerNo', 'card1', 'card2', 'card3', 'card4', 'card5', 'sumofcards',
#        'dealcard1', 'dealcard2', 'dealcard3', 'dealcard4', 'dealcard5',
#        'sumofdeal', 'blkjck', 'winloss', 'plybustbeat', 'dlbustbeat',
#        'plwinamt', 'dlwinamt', 'ply2cardsum'],
#       dtype='object')

# %%
# select columns
y = df.winloss
X = df.drop(columns='winloss')

# %%
# remove # index
X.set_index('PlayerNo', inplace=True)

# %%
# replace all strings for #s
X = pd.get_dummies(X)

# %%
# split data into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
# Select model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# /Users/caitlinsmith/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Prediction score
model.score(X_test,y_test)
# Out:
# 1.0

# %%
X_test
# Out:
#           card1  card2  card3  card4  card5  sumofcards  dealcard1  dealcard2  \
# PlayerNo
# Player5      10      9      0      0      0          19          6          5
# Player2       4      7      6      0      0          17         11          1
# Player2       2      3      6      3      1          15         11          2
# Player3       3     10      0      0      0          13          5          2
# Player4       7      2      3      3      3          18          7         11
# ...         ...    ...    ...    ...    ...         ...        ...        ...
# Player1       8     10      0      0      0          18          4          5
# Player3       2      6     10      0      0          18          8         10
# Player3       1      4      9      0      0          14          4          1
# Player2       9      4      0     10      0          23          9         10
# Player3      11      8      0      0      0          19          3         10
#
#           dealcard3  dealcard4  ...  plybustbeat_Beat  plybustbeat_Bust  \
# PlayerNo                        ...
# Player5           4          8  ...                 0                 0
# Player2           1          4  ...                 0                 0
# Player2           5          0  ...                 1                 0
# Player3          10          0  ...                 1                 0
# Player4           0          0  ...                 0                 0
# ...             ...        ...  ...               ...               ...
# Player1          11          0  ...                 1                 0
# Player3           0          0  ...                 0                 0
# Player3          10         10  ...                 0                 0
# Player2           0          0  ...                 0                 1
# Player3           9          0  ...                 0                 0
#
#           plybustbeat_DlBust  plybustbeat_Plwin  plybustbeat_Push  \
# PlayerNo
# Player5                    1                  0                 0
# Player2                    0                  0                 1
# Player2                    0                  0                 0
# Player3                    0                  0                 0
# Player4                    0                  0                 1
# ...                      ...                ...               ...
# Player1                    0                  0                 0
# Player3                    0                  0                 1
# Player3                    1                  0                 0
# Player2                    0                  0                 0
# Player3                    1                  0                 0
#
#           dlbustbeat_Beat  dlbustbeat_Bust  dlbustbeat_Dlwin  \
# PlayerNo
# Player5                 0                1                 0
# Player2                 0                0                 0
# Player2                 0                0                 1
# Player3                 0                0                 1
# Player4                 0                0                 0
# ...                   ...              ...               ...
# Player1                 0                0                 1
# Player3                 0                0                 0
# Player3                 0                1                 0
# Player2                 0                0                 0
# Player3                 0                1                 0
#
#           dlbustbeat_PlBust  dlbustbeat_Push
# PlayerNo
# Player5                   0                0
# Player2                   0                1
# Player2                   0                0
# Player3                   0                0
# Player4                   0                1
# ...                     ...              ...
# Player1                   0                0
# Player3                   0                1
# Player3                   0                0
# Player2                   1                0
# Player3                   0                0
#
# [225000 rows x 27 columns]

# %%
# Comfirming prediction
# selecting player
player = X_test[0:1]

# %%
# Should get a win
y_test[0:1]
# Out:
# 141292    Win
# Name: winloss, dtype: object

# %%
model.predict(player)
# Out:
# array(['Win'], dtype=object)
